# %% [markdown]
# <a href="https://colab.research.google.com/github/ANUDHEERPARIMI/PyTorch/blob/PyTorch/Autograd_Neural_Net.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %% [markdown]
# x->w->sigmoid->y_pred->Loss

# %% [markdown]
# Normal Calculation

# %%
y=torch.tensor(0.0)
x=torch.tensor(6.7)

w=torch.tensor(1.0)
b=torch.tensor(0.0)

# %%
def binary_cross_entropy_loss(y_pred, y_true):
    ep=1e-8
    y_pred=torch.clamp(y_pred,ep,1-ep)
    return -torch.mean(y_true * torch.log(y_pred) + (1 - y_true) * torch.log(1 - y_pred))

# %%
z=w*x+b
y_pred=torch.sigmoid(z)
Loss=binary_cross_entropy_loss(y_pred,y)

# %%
Loss
# Out:
# tensor(6.7012)

# %%
z
# Out:
# tensor(6.7000)

# %%
#Derivatives

dloss_dy_pred=(y_pred-y)/(y_pred*(1-y_pred))

dy_pred_dz=y_pred*(1-y_pred)

dz_dw=x
dz_db=1

dloss_dw=dloss_dy_pred*dy_pred_dz*dz_dw
dloss_db=dloss_dy_pred*dy_pred_dz*dz_db

# %%
dloss_dw
# Out:
# tensor(6.6918)

# %%
dloss_db
# Out:
# tensor(0.9988)

# %% [markdown]
# Using AutoGrad

# %%
y=torch.tensor(0.0)
x=torch.tensor(6.7)

w=torch.tensor(1.0,requires_grad=True)
b=torch.tensor(0.0,requires_grad=True)

# %%
z=w*x+b

# %%
z
# Out:
# tensor(6.7000, grad_fn=<AddBackward0>)

# %%
y_pred=torch.sigmoid(z)

# %%
loss=binary_cross_entropy_loss(y_pred,y)

# %%
loss
# Out:
# tensor(6.7012, grad_fn=<NegBackward0>)

# %%
loss.backward()

# %%
w.grad
# Out:
# tensor(6.6918)

# %%
b.grad
# Out:
# tensor(0.9988)

# %%
#Vector Level

# %%
x=torch.tensor([1.0,2.0,3.0],requires_grad=True)

# %%
y=(x**2).sum()

# %%
y.backward()

# %%
x.grad
# Out:
# tensor([2., 4., 6.])

# %%
x.grad.zero_()
# Out:
# tensor([0., 0., 0.])

# %%
x
# Out:
# tensor([1., 2., 3.], requires_grad=True)

# %% [markdown]
# Detach gradient

# %%
x.requires_grad_(False)
# Out:
# tensor([1., 2., 3.])

# %%
y.backward()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-1055444503.py in <cell line: 0>()
# ----> 1 y.backward()
#
# /usr/local/lib/python3.12/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     645                 inputs=inputs,
#     646             )
# --> 647         torch.autograd.backward(
#     648             self, gradient, retain_graph, create_graph, inputs=inputs
#     649         )
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     352     # some Python versions print out the first line of a multi-line function
#     353     # calls in the traceback and some print out the last line
# --> 354     _engine_run_backward(
#     355         tensors,
#     356         grad_tensors_,
#
# ...

# %%
x=torch.tensor(2.0,requires_grad=True)
x
# Out:
# tensor(2., requires_grad=True)

# %%
z=x.detach()
z
# Out:
# tensor(2.)

# %%
z
# Out:
# tensor(2.)

# %%
y=x**2

# %%
y
# Out:
# tensor(4., grad_fn=<PowBackward0>)

# %%
z.backward()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-148511205.py in <cell line: 0>()
# ----> 1 z.backward()
#
# /usr/local/lib/python3.12/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     645                 inputs=inputs,
#     646             )
# --> 647         torch.autograd.backward(
#     648             self, gradient, retain_graph, create_graph, inputs=inputs
#     649         )
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     352     # some Python versions print out the first line of a multi-line function
#     353     # calls in the traceback and some print out the last line
# --> 354     _engine_run_backward(
#     355         tensors,
#     356         grad_tensors_,
#
# ...

# %%
y.backward()

# %%
x=torch.tensor(2.0,requires_grad=True)
x
# Out:
# tensor(2., requires_grad=True)
