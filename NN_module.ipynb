# %% [markdown]
# Using nn module
# Built in activation function
# Built in loss function
# Built in optimizer

# %%
import torch
import torch.nn as nn

# %%
class Model(nn.Module):
  def __init__(self,num_features):
    super().__init__()
    self.linear = nn.Linear(num_features,1)
    self.sigmoid=nn.Sigmoid()
  def forward(self,x):
    out=self.linear(x)
    out=self.sigmoid(out)
    return out

# %%
features=torch.rand(10,5)
model=Model(features.shape[1])
model(features)
# Out:
# tensor([[0.5882],
#         [0.6706],
#         [0.5949],
#         [0.6819],
#         [0.6113],
#         [0.5865],
#         [0.6966],
#         [0.6783],
#         [0.6535],
#         [0.6212]], grad_fn=<SigmoidBackward0>)

# %%
model.linear.weight
# Out:
# Parameter containing:
# tensor([[ 0.0242,  0.3332, -0.0588, -0.2151,  0.3479]], requires_grad=True)

# %%
model.linear.bias
# Out:
# Parameter containing:
# tensor([0.4100], requires_grad=True)

# %%
# !pip install torchinfo
# Out:
# Requirement already satisfied: torchinfo in /usr/local/lib/python3.12/dist-packages (1.8.0)

# %%
from torchinfo import summary
summary(model,input_size=(10,5))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Model                                    [10, 1]                   --
# ├─Linear: 1-1                            [10, 1]                   6
# ├─Sigmoid: 1-2                           [10, 1]                   --
# ==========================================================================================
# Total params: 6
# Trainable params: 6
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 0.00
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ==========================================================================================

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Model(nn.Module):
  def __init__(self,feature):
    super().__init__()
    self.linear1=nn.Linear(feature,3)
    self.relu=nn.ReLU()
    self.linear2=nn.Linear(3,1)
    self.sigmoid=nn.Sigmoid()
  def forward(self,features):
    out=self.linear1(features)
    out1=self.relu(out)
    out2=self.linear2(out1)
    out3=self.sigmoid(out2)
    return out3

# %%
features=torch.rand(10,5)
model=Model(features.shape[1])
model(features)
# Out:
# tensor([[0.3833],
#         [0.3776],
#         [0.3878],
#         [0.3871],
#         [0.3776],
#         [0.3888],
#         [0.3786],
#         [0.3849],
#         [0.3785],
#         [0.3815]], grad_fn=<SigmoidBackward0>)

# %%
model.linear1.weight #15x3
# Out:
# Parameter containing:
# tensor([[-0.2681, -0.0027, -0.3085, -0.2458,  0.3639],
#         [ 0.1624,  0.2486, -0.4155,  0.1214, -0.2383],
#         [-0.4034, -0.0625, -0.2413, -0.1585,  0.3828]], requires_grad=True)

# %%
summary(model)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# Model                                    --
# ├─Linear: 1-1                            18
# ├─ReLU: 1-2                              --
# ├─Linear: 1-3                            4
# ├─Sigmoid: 1-4                           --
# =================================================================
# Total params: 22
# Trainable params: 22
# Non-trainable params: 0
# =================================================================

# %% [markdown]
# Sequential

# %%
class Model(nn.Module):
  def __init__(self,feature):
    super().__init__()
    self.network=nn.Sequential(
        nn.Linear(feature,3),
        nn.ReLU(),
        nn.Linear(3,1),
        nn.Sigmoid())
  def forward(self,features):
    out=self.network(features)
    return out

# %%
features=torch.rand(10,5)
model=Model(features.shape[1])
model(features)
# Out:
# tensor([[0.5027],
#         [0.4512],
#         [0.4445],
#         [0.4813],
#         [0.5494],
#         [0.5078],
#         [0.4699],
#         [0.4944],
#         [0.4494],
#         [0.4928]], grad_fn=<SigmoidBackward0>)
